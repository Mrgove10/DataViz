# %% [markdown]
# # DataViz

# %%
#installing dependencies
# !pip install pandas mysql-connector-python python-dotenv
# Out:
# ...
# WARNING: Ignoring invalid distribution -yrsistent (c:\users\richa\appdata\local\programs\python\python37\lib\site-packages)
# WARNING: Ignoring invalid distribution -yrsistent (c:\users\richa\appdata\local\programs\python\python37\lib\site-packages)
# WARNING: Ignoring invalid distribution -yrsistent (c:\users\richa\appdata\local\programs\python\python37\lib\site-packages)
# WARNING: Ignoring invalid distribution -yrsistent (c:\users\richa\appdata\local\programs\python\python37\lib\site-packages)
# WARNING: Ignoring invalid distribution -yrsistent (c:\users\richa\appdata\local\programs\python\python37\lib\site-packages)
# WARNING: Ignoring invalid distribution -yrsistent (c:\users\richa\appdata\local\programs\python\python37\lib\site-packages)
# WARNING: You are using pip version 21.1.3; however, version 21.3.1 is available.
# You should consider upgrading via the 'c:\users\richa\appdata\local\programs\python\python37\python.exe -m pip install --upgrade pip' command.

# %%
# imports
import pandas as pd
import mysql.connector
import os
from dotenv import load_dotenv

load_dotenv()
# Out:
# True

# %%
# Database connection

config = {
  'user': os.getenv('USER'),
  'password': os.getenv('PASSWORD'),
  'host': '192.168.1.38',
  'database': 'DATAVIZ',
  'raise_on_warnings': True
}

cnx = mysql.connector.connect(**config)

# Check if connection was successful
if (cnx):
    # Carry out normal procedure
    print("Connection successful")
else:
    # Terminate
    print("Connection unsuccessful")

#cnx.close()
# Out:
# Connection successful

# %%
# Clear tables 
# uncoment the folowing line if you with to clear the tables
flushdata=True

# %%
# Define data types

dtype_base_sirene = {
    "siren": "int",
    "nic": "int",
    "siret": "int",
    "statutdiffusionetablissement": "string",
    "datecreationetablissement": "string",
    "trancheeffectifsetablissement": "string",
    "anneeeffectifsetablissement": "string",
    "activiteprincipaleregistremetiersetablissement": "string",
    "datederniertraitementetablissement": "string",
    "etablissementsiege": "string",
    "nombreperiodesetablissement": "int",
    "complementadresseetablissement": "string",
    "numerovoieetablissement": "int",
    "indicerepetitionetablissement": "string",
    "typevoieetablissement": "string",
    "libellevoieetablissement": "string",
    "codepostaletablissement": "string",
    "libellecommuneetablissement": "string",
    "libellecommuneetrangeretablissement": "string",
    "distributionspecialeetablissement": "string",
    "codecommuneetablissement": "int",
    "codecedexetablissement": "int",
    "libellecedexetablissement": "string",
    "codepaysetrangeretablissement": "string",
    "libellepaysetrangeretablissement": "string",
    "complementadresse2etablissement": "string",
    "numerovoie2etablissement": "int",
    "indicerepetition2etablissement": "string",
    "typevoie2etablissement": "string",
    "libellevoie2etablissement": "string",
    "codepostal2etablissement": "string",
    "libellecommune2etablissement": "string",
    "libellecommuneetranger2etablissement": "string",
    "distributionspeciale2etablissement": "string",
    "codecommune2etablissement": "int",
    "codecedex2etablissement": "int",
    "libellecedex2etablissement": "string",
    "codepaysetranger2etablissement": "string",
    "libellepaysetranger2etablissement": "string",
    "datedebutetablissement": "string",
    "etatadministratifetablissement": "string",
    "enseigne1etablissement": "string",
    "enseigne2etablissement": "string",
    "enseigne3etablissement": "string",
    "denominationusuelleetablissement": "string",
    "activiteprincipaleetablissement": "string",
    "nomenclatureactiviteprincipaleetablissement": "string",
    "caractereemployeuretablissement": "string",
    "codeepcietablissement": "int",
    "epcietablissement": "string",
    "altitudemoyennecommuneetablissement": "string",
    "superficiecommuneetablissement": "int",
    "populationcommuneetablissement": "string",
    "codearrondissementetablissement": "int",
    "codedepartementetablissement": "int",
    "departementetablissement": "string",
    "coderegionetablissement": "int",
    "regionetablissement": "string",
    "sectionetablissement": "string",
    "soussectionetablissement": "string",
    "divisionetablissement": "string",
    "groupeetablissement": "string",
    "classeetablissement": "string",
    "adresseetablissement": "string",
    "datefermetureetablissement": "string",
    "statutdiffusionunitelegale": "int",
    "unitepurgeeunitelegale": "string",
    "datecreationunitelegale": "string",
    "sigleunitelegale": "string",
    "sexeunitelegale": "string",
    "prenom1unitelegale": "string",
    "prenom2unitelegale": "string",
    "prenom3unitelegale": "string",
    "prenom4unitelegale": "string",
    "prenomusuelunitelegale": "string",
    "pseudonymeunitelegale": "string",
    "identifiantassociationunitelegale": "string",
    "trancheeffectifsunitelegale": "string",
    "anneeeffectifsunitelegale": "string",
    "datederniertraitementunitelegale": "string",
    "nombreperiodesunitelegale": "int",
    "categorieentreprise": "string",
    "anneecategorieentreprise": "string",
    "datedebutunitelegale": "string",
    "etatadministratifunitelegale": "string",
    "nomunitelegale": "string",
    "nomusageunitelegale": "string",
    "denominationunitelegale": "string",
    "denominationusuelle1unitelegale": "string",
    "denominationusuelle2unitelegale": "string",
    "denominationusuelle3unitelegale": "string",
    "categoriejuridiqueunitelegale": "int",
    "activiteprincipaleunitelegale": "string",
    "nomenclatureactiviteprincipaleunitelegale": "string",
    "nicsiegeunitelegale": "int",
    "economiesocialesolidaireunitelegale": "string",
    "caractereemployeurunitelegale": "string",
    "sectionunitelegale": "string",
    "soussectionunitelegale": "string",
    "divisionunitelegale": "string",
    "groupeunitelegale": "string",
    "classeunitelegale": "string",
    "siretsiegeunitelegale": "int",
    "naturejuridiqueunitelegale": "string",
    "l1_adressage_unitelegale": "string",
    "datefermetureunitelegale": "string",
    "filename": "string",
    "geolocetablissement": "string",
}


dtype_effectifs_etudiants = {
    "Année universitaire": "string",
    "Niveau géographique": "string",
    "Unité géographique": "string",
    "regroupement": "string",
    "Regroupements de formations ou d’établissements": "string",
    "secteur": "string",
    "Secteur de l’établissement d’inscription": "string",
    "sexe": "string",
    "Sexe de l’étudiant": "string",
    "Nombre total d’étudiants inscrits": "string",
    "Nombre total d’étudiants inscrits hors doubles inscriptions université/CPGE (voir documentation)": "string",
    "A des effectifs en formations de DUT": "string",
    "Nombre d’étudiants inscrits en DUT": "string",
    "A des effectifs en formations d'ingénieurs": "string",
    "Nombre d’étudiants inscrits dans les formations d’Ingénieur": "string",
    "A des effectifs en master MEEF dans les ESPE et INSPE": "string",
    "Nombre d’étudiants inscrits dans les master MEEF dans les ESPE et INSPE": "string",
    "diffusable": "string",
    "Données diffusables": "string",
    "secret": "string",
    "Données soumises au secret statistique": "string",
    "niveau_geo": "string",
    "Identifiant de l’unité géographique": "string",
    "Identifiant de la région": "string",
    "Identifiant de l'académie": "string",
    "Identifiant du département": "string",
    "Identifiant de l'unité urbaine": "string",
    "Rentrée": "string",
    "Année civile concernée": "string",
}


dtype_ircom = {
    "dep": "string",
    "depcom": "string",
    "nom_commune": "string",
    "nb_foyers": "int",
    "revenu_fiscal_ref": "int",
    "impot_net": "int",
    "nb_foyers_imposables": "int",
    "revenu_fiscal_ref_foyers_imposables": "int",
    "nb_foyers_traitements_salaires": "int",
    "montant_traitements_salaires": "int",
    "nb_foyers_retraites_pensions": "int",
    "montant_retraites_pensions": "int",
}


dtype_foncier = {
    "Code service CH": "string",
    "Reference document": "string",
    "1 Articles CGI": "string",
    "2 Articles CGI": "string",
    "3 Articles CGI": "string",
    "4 Articles CGI": "string",
    "5 Articles CGI": "string",
    "No disposition": "int",
    "Date mutation": "string",
    "Nature mutation": "string",
    "Valeur fonciere": "int",
    "No voie": "int",
    "B/T/Q": "string",
    "Type de voie": "string",
    "Code voie": "string",
    "Voie": "string",
    "Code postal": "string",
    "Commune": "string",
    "Code departement": "string",
    "Code commune": "string",
    "Prefixe de section": "string",
    "Section": "string",
    "No plan": "string",
    "No Volume": "string",
    "1er lot": "string",
    "Surface Carrez du 1er lot": "string",
    "2eme lot": "string",
    "Surface Carrez du 2eme lot": "string",
    "3eme lot": "string",
    "Surface Carrez du 3eme lot": "string",
    "4eme lot": "string",
    "Surface Carrez du 4eme lot": "string",
    "5eme lot": "string",
    "Surface Carrez du 5eme lot": "string",
    "Nombre de lots": "string",
    "Code type local": "string",
    "Type local": "string",
    "Identifiant local": "string",
    "Surface reelle bati": "string",
    "Nombre pieces principales": "string",
    "Nature culture": "string",
    "Nature culture speciale": "string",
    "Surface terrain": "string",
}

# %%
#Create mysql tables
cursor = cnx.cursor()

if flushdata: cursor.execute("DROP TABLE IF EXISTS `ircom`")
#ircom
cursor.execute("""CREATE TABLE ircom (
                id INT AUTO_INCREMENT PRIMARY KEY, 
                dep INT, 
                depcom VARCHAR(255),
                nom_commune VARCHAR(255),
                nb_foyers INT,
                revenu_fiscal_ref INT,
                impot_net INT,
                nb_foyers_imposables INT,
                revenu_fiscal_ref_foyers_imposables INT,
                nb_foyers_traitements_salaires INT,
                montant_traitements_salaires INT,
                nb_foyers_retraites_pensions INT,
                montant_retraites_pensions INT)
                """)

#valeur fonciere
cursor.execute("""CREATE TABLE val_fonc (
                id INT AUTO_INCREMENT PRIMARY KEY, 
                
                )
                """
)

#Equipe serv
cursor.execute("""CREATE TABLE val_fonc (
                id INT AUTO_INCREMENT PRIMARY KEY, 
                
                )
                """
)

#equipcommerce
cursor.execute("""CREATE TABLE val_fonc (
                id INT AUTO_INCREMENT PRIMARY KEY, 
                
                )
                """
)

#equipe santé
cursor.execute("""CREATE TABLE val_fonc (
                id INT AUTO_INCREMENT PRIMARY KEY, 
                
                )
                """
)

#atlasregional
cursor.execute("""CREATE TABLE val_fonc (
                id INT AUTO_INCREMENT PRIMARY KEY, 
                
                )
                """
)

#geo ref
cursor.execute("""CREATE TABLE val_fonc (
                id INT AUTO_INCREMENT PRIMARY KEY, 
                
                )
                """
)
# Out:
# ---------------------------------------------------------------------------
# MySQLInterfaceError                       Traceback (most recent call last)
# ~\AppData\Local\Programs\Python\Python37\lib\site-packages\mysql\connector\connection_cext.py in cmd_query(self, query, raw, buffered, raw_as_string)
#     519                                raw_as_string=raw_as_string,
# --> 520                                query_attrs=self._query_attrs)
#     521         except MySQLInterfaceError as exc:
#
# MySQLInterfaceError: You have an error in your SQL syntax; check the manual that corresponds to your MariaDB server version for the right syntax to use near ')' at line 4
#
# During handling of the above exception, another exception occurred:
#
# ProgrammingError                          Traceback (most recent call last)
# ~\AppData\Local\Temp/ipykernel_8576/346206817.py in <module>
#      25
#      26                 )
# ---> 27                 """
#      28 )
#      29
#
# ...

# %%
#read a CSV file

#ircom
ircom2017CSV = pd.read_csv('data/ircom2017.csv', dtype=dtype_ircom)
ircom2017CSV.dtypes
del ircom2017CSV


#ircom2018CSV = pd.read_csv('data/ircom2018.csv')#, dtype = {'nb_foyers':str})
#ircom2019CSV = pd.read_csv('data/ircom2019.csv')

#valeur fonciere
valeursfonciere2018CSV = pd.read_csv('data/valeursfoncieres-2018.txt',sep='|',engine='python',dtype=dtype_foncier)
valeursfonciere2018CSV.dypes
valeursfonciere2018CSV.head()
del valeursfonciere2018CSV
valeursfonciere2019CSV = pd.read_csv('data/valeursfoncieres-2019.txt',sep='|',engine='python',dtype=dtype_foncier)
valeursfonciere2019CSV.head()
del valeursfonciere2019CSV
valeursfonciere2020CSV = pd.read_csv('data/valeursfoncieres-2020.txt',sep='|',engine='python',dtype=dtype_foncier)
valeursfonciere2020CSV.head()
del valeursfonciere2020CSV
valeursfonciere2021CSV = pd.read_csv('data/valeursfoncieres-2021-s1.txt',sep='|',engine='python',dtype=dtype_foncier)
valeursfonciere2021CSV.head()
del valeursfonciere2021CSV

#Equipe serv

#equipcommerce

#equipe santé

#atlasregional

#geo ref


# ircom2018CSV.head()
# ircom2018CSV.columns
# ircom2018CSV.dtypes
# Out:
# ---------------------------------------------------------------------------
# TypeError                                 Traceback (most recent call last)
# pandas\_libs\parsers.pyx in pandas._libs.parsers.TextReader._convert_tokens()
#
# TypeError: Cannot cast array data from dtype('O') to dtype('int32') according to the rule 'safe'
#
# During handling of the above exception, another exception occurred:
#
# ValueError                                Traceback (most recent call last)
# ~\AppData\Local\Temp/ipykernel_8576/450943371.py in <module>
#       2
#       3 #ircom
# ----> 4 ircom2017CSV = pd.read_csv('data/ircom2017.csv', dtype=dtype_ircom)
#       5 ircom2017CSV.dtypes
#       6 del ircom2017CSV
#
# ...

# %%
ircm2018CSV.info()

# %%
ircm2018CSV.describe()

# %%
# Out:
# 'touch' is not recognized as an internal or external command,
# operable program or batch file.
